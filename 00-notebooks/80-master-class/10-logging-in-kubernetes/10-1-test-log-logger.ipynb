# %%
from playLib.log_logger import log_make_logger

# %%
log=log_make_logger('myJupTest')
# Out:
# 2020-04-04 14:39:52,406 - myJupTest - INFO - Logging Begins

# %%
log.error('It actually works - surprised?')
# Out:
# 2020-04-04 14:40:14,549 - myJupTest - ERROR - It actually works - surprised?

# %%
! pip install --user awscli
# Out:
# ...
#      |████████████████████████████████| 3.0 MB 4.2 MB/s eta 0:00:01     |████▌                           | 419 kB 4.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 46 kB 9.1 MB/s  eta 0:00:01
# ...

# %%
! aws s3 ls ga-et-data/inputsv0/air_temperature/
# Out:
# 2020-02-26 05:05:00         83 tavg_001.tfw
# 2020-02-26 05:05:00   13167138 tavg_001.tif
# 2020-02-26 05:05:00        624 tavg_001.tif.aux.xml
# 2020-02-26 05:05:00    2299911 tavg_001.tif.ovr
# 2020-02-26 05:05:01          5 tavg_001.tif.vat.cpg
# 2020-02-26 05:05:00       2588 tavg_001.tif.vat.dbf
# 2020-02-26 05:05:00         83 tavg_002.tfw
# 2020-02-26 05:05:00   13061439 tavg_002.tif
# 2020-02-26 05:05:00        624 tavg_002.tif.aux.xml
# 2020-02-26 05:05:01          5 tavg_002.tif.vat.cpg
# 2020-02-26 05:05:00       2768 tavg_002.tif.vat.dbf
# 2020-02-26 05:05:00         83 tavg_003.tfw
# 2020-02-26 05:05:00   13200958 tavg_003.tif
# 2020-02-26 05:05:00        623 tavg_003.tif.aux.xml
# 2020-02-26 05:05:01    2308276 tavg_003.tif.ovr
# 2020-02-26 05:05:01          5 tavg_003.tif.vat.cpg
# 2020-02-26 05:05:01       2558 tavg_003.tif.vat.dbf
# 2020-02-26 05:05:01         83 tavg_004.tfw
# 2020-02-26 05:05:01   13103801 tavg_004.tif
# ...
